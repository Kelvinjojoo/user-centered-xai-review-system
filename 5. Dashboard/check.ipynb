# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# Load dataset
df = pd.read_csv("yelp_dataset_with_text.csv")

# %%
df = df.drop(columns=['lemmatized_dl', 'lemmatized_bert'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7670 entries, 0 to 7669
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_name           7670 non-null   object
#  1   review_id               7670 non-null   object
#  2   user_id                 7670 non-null   object
#  3   date                    7670 non-null   object
#  4   stars_review            7670 non-null   int64
#  5   stars_business_average  7670 non-null   int64
#  6   normalized_text         7670 non-null   object
#  7   lemmatized_ml           7670 non-null   object
#  8   sentiment_label         7670 non-null   object
#  9   daily_spike_score       7670 non-null   float64
#  10  hourly_spike_score      7670 non-null   float64
#  11  is_fake                 7670 non-null   int64
#  12  max_similarity_score    7670 non-null   float64
#  13  most_similar_review_id  7670 non-null   object
# ...

# %%
df.head()
# Out:
#        business_name               review_id                 user_id  \
# 0  Acme Oyster House  qdpoNaAd2d8hz354jRKryg  M2jgPvf6syoOHGW0R8PotQ
# 1  Acme Oyster House  5t14YNj5mji1aoIbt3uoQQ  akv8uZ1X6POqCWXYcnbXfA
# 2  Acme Oyster House  b2lwJxRgseknM_0B5cRkFQ  2zhTsvYOEPQaQP9w53zkvA
# 3  Acme Oyster House  _BAe5c9nCJh7ntBo2YMqsQ  eZGoPMRfq2hw5LfwJg0uTA
# 4  Acme Oyster House  rFeHUzOELJlba9vHxvR6Ug  uBvrdhNSlGnN35NA8cSMwQ
#
#                   date  stars_review  stars_business_average  \
# 0  2012-02-07 00:05:19             2                       4
# 1  2015-02-24 01:49:26             4                       4
# 2  2010-01-07 18:09:30             2                       4
# 3  2010-01-07 18:12:23             3                       4
# 4  2010-01-11 02:27:03             4                       4
#
# ...

# %%
dummy_row = {
    'business_name': 'Acme Oyster House',
    'review_id': 'dummy_review_001',
    'user_id': 'dummy_user_001',
    'date': '2025-11-23 12:00:00',
    'stars_review': 4,
    'stars_business_average': 4,
    'normalized_text': 'Good food with fast service and clean place overall very nice',
    'lemmatized_ml': [
        'good', 'food', 'fast', 'service', 'clean', 'place', 'overall', 'nice'
    ],
    'sentiment_label': 'positive',
    'daily_spike_score': 0.0,
    'hourly_spike_score': 0.0,
    'is_fake': 0,
    'max_similarity_score': 0.0,
    'most_similar_review_id': '-',
    'text': 'Good food with fast service and a clean place, overall very nice.'
}

dummy_df = pd.DataFrame([dummy_row])
df = pd.concat([dummy_df, df], ignore_index=True)

# %%
df.head()
# Out:
#        business_name               review_id                 user_id  \
# 0  Acme Oyster House        dummy_review_001          dummy_user_001
# 1  Acme Oyster House  qdpoNaAd2d8hz354jRKryg  M2jgPvf6syoOHGW0R8PotQ
# 2  Acme Oyster House  5t14YNj5mji1aoIbt3uoQQ  akv8uZ1X6POqCWXYcnbXfA
# 3  Acme Oyster House  b2lwJxRgseknM_0B5cRkFQ  2zhTsvYOEPQaQP9w53zkvA
# 4  Acme Oyster House  _BAe5c9nCJh7ntBo2YMqsQ  eZGoPMRfq2hw5LfwJg0uTA
#
#                   date  stars_review  stars_business_average  \
# 0  2025-11-23 12:00:00             4                       4
# 1  2012-02-07 00:05:19             2                       4
# 2  2015-02-24 01:49:26             4                       4
# 3  2010-01-07 18:09:30             2                       4
# 4  2010-01-07 18:12:23             3                       4
#
# ...

# %%
# Frasa yang ingin dicari
keyword = "Ehhhhh"

# Filter baris yang mengandung frasa tersebut
filtered_df = df[df['text'].str.contains(keyword, case=False, na=False)]


filtered_df
# Out:
#           business_name               review_id                 user_id  \
# 2681  Acme Oyster House  fok6WZcFOiqHm4_hTNjUCA  lUPSEbFRd3jDOM5agGnjWQ
# 4070  Acme Oyster House  u2GxsNjYRlt7YKLkX0OrSQ  HkJb40r9mKC8dyL1nTzSiw
#
#                      date  stars_review  stars_business_average  \
# 2681  2015-03-03 15:06:39             4                       4
# 4070  2018-01-06 02:24:57             2                       4
#
# ...

# %%
df.describe()
# Out:
#        stars_review  stars_business_average  daily_spike_score  \
# count   7671.000000                  7671.0        7671.000000
# mean       4.125407                     4.0           0.831743
# std        1.067314                     0.0           1.041446
# min        1.000000                     4.0           0.000000
# 25%        4.000000                     4.0           0.000000
# 50%        4.000000                     4.0           0.546965
# 75%        5.000000                     4.0           1.251283
# max        5.000000                     4.0           5.477197
#
#        hourly_spike_score      is_fake  max_similarity_score
# count         7671.000000  7671.000000           7671.000000
# mean             0.461627     0.117195              0.323882
# std              1.325818     0.321673              0.103858
# min              0.000000     0.000000              0.000000
# 25%              0.000000     0.000000              0.258597
# ...

# %%
df.to_csv("Dummy_yelp_dataset_with_text.csv", index=False)
