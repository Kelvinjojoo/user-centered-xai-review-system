# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from scipy.sparse import hstack, csr_matrix
import shap
from collections import Counter
import lime
import lime.lime_tabular
from imblearn.over_sampling import SMOTE
import warnings
import joblib

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from scipy.sparse import hstack, csr_matrix
import shap
from collections import Counter
import lime
import lime.lime_tabular
from imblearn.over_sampling import SMOTE
import warnings
import joblib
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("yelp_dataset_after_finalization.csv")

df.head()
# Out:
#        business_name               review_id                 user_id  \
# 0  Acme Oyster House  qdpoNaAd2d8hz354jRKryg  M2jgPvf6syoOHGW0R8PotQ
# 1  Acme Oyster House  5t14YNj5mji1aoIbt3uoQQ  akv8uZ1X6POqCWXYcnbXfA
# 2  Acme Oyster House  b2lwJxRgseknM_0B5cRkFQ  2zhTsvYOEPQaQP9w53zkvA
# 3  Acme Oyster House  _BAe5c9nCJh7ntBo2YMqsQ  eZGoPMRfq2hw5LfwJg0uTA
# 4  Acme Oyster House  rFeHUzOELJlba9vHxvR6Ug  uBvrdhNSlGnN35NA8cSMwQ
#
#                   date  stars_review  stars_business_average  \
# 0  2012-02-07 00:05:19             2                       4
# 1  2015-02-24 01:49:26             4                       4
# 2  2010-01-07 18:09:30             2                       4
# 3  2010-01-07 18:12:23             3                       4
# 4  2010-01-11 02:27:03             4                       4
#
#                                      normalized_text  \
# 0  I grew upon seafood corn meal breaded seafood ...
# 1  The Acme is a long time favorite At the age of...
# 2  A tourist site with the soul of a TGI Friday s...
# 3  The wife and I had dinner there in January We ...
# 4  Based on the Yelp reviews I stopped by Acme Oy...
#
#                                        lemmatized_ml  \
# 0  ['grow', 'upon', 'seafood', 'corn', 'meal', 'b...
# 1  ['acme', 'long', 'time', 'favorite', 'age', 'd...
# 2  ['tourist', 'site', 'soul', 'tgi', 'friday', '...
# 3  ['wife', 'dinner', 'january', 'go', 'early', '...
# 4  ['base', 'yelp', 'review', 'stop', 'acme', 'ho...
#
#                                        lemmatized_dl  \
# 0  ['grow', 'upon', 'seafood', 'corn', 'meal', 'b...
# 1  ['acme', 'long', 'time', 'favorite', 'age', 'd...
# 2  ['tourist', 'site', 'soul', 'tgi', 'friday', '...
# 3  ['wife', 'dinner', 'january', 'go', 'early', '...
# 4  ['base', 'yelp', 'review', 'stop', 'acme', 'ho...
#
#                                      lemmatized_bert sentiment_label  \
# 0  ['i', 'grow', 'upon', 'seafood', 'corn', 'meal...        negative
# 1  ['the', 'acme', 'be', 'a', 'long', 'time', 'fa...        positive
# 2  ['a', 'tourist', 'site', 'with', 'the', 'soul'...        negative
# 3  ['the', 'wife', 'and', 'i', 'have', 'dinner', ...        positive
# 4  ['base', 'on', 'the', 'yelp', 'review', 'i', '...        positive
#
#    daily_spike_score  hourly_spike_score  is_fake  max_similarity_score  \
# 0           0.000000            3.592276        0              0.264060
# 1           1.251283            3.592276        1              0.259275
# 2           0.546965            3.592276        1              0.234411
# 3           0.546965            3.592276        1              0.260815
# 4           0.546965            3.592276        1              0.320177
#
#    most_similar_review_id
# 0  TiRy733reHgq5v9_ePcJSA
# 1  3futyMTxE8viSKTBdkM03g
# 2  h6h7cvApI6aIV9Wdg__pPQ
# 3  yKLuUKdwcvtGCBYuBi3X4A
# 4  7BBjoF6ihpS9s6f3F0iajQ

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7670 entries, 0 to 7669
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_name           7670 non-null   object
#  1   review_id               7670 non-null   object
#  2   user_id                 7670 non-null   object
#  3   date                    7670 non-null   object
#  4   stars_review            7670 non-null   int64
#  5   stars_business_average  7670 non-null   int64
#  6   normalized_text         7670 non-null   object
#  7   lemmatized_ml           7670 non-null   object
#  8   lemmatized_dl           7670 non-null   object
#  9   lemmatized_bert         7670 non-null   object
#  10  sentiment_label         7670 non-null   object
#  11  daily_spike_score       7670 non-null   float64
#  12  hourly_spike_score      7670 non-null   float64
#  13  is_fake                 7670 non-null   int64
#  14  max_similarity_score    7670 non-null   float64
#  15  most_similar_review_id  7670 non-null   object
# dtypes: float64(3), int64(3), object(10)
# memory usage: 958.9+ KB

# %% [markdown]
# # Analyze Imbalance Data

# %%
class_distribution = df['sentiment_label'].value_counts()
print("Class Distribution:")
print(class_distribution)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
class_distribution.plot(kind='bar', color=['skyblue', 'salmon', 'lightgreen'])
plt.title('Distribution of Sentiment Labels')
plt.xlabel('Sentiment Label')
plt.ylabel('Count')
plt.xticks(rotation=0)

plt.subplot(1, 2, 2)
plt.pie(class_distribution.values, labels=class_distribution.index, autopct='%1.1f%%', colors=['lightblue', 'lightcoral', 'lightgreen'])
plt.title('Sentiment Proportion')

plt.tight_layout()
plt.show()
# Out:
# Class Distribution:
# sentiment_label
# positive    6263
# negative    1069
# neutral      338
# Name: count, dtype: int64

# %% [markdown]
# # PREPROCESS TEXT DATA

# %%
def tokens_to_string(tokens):
    if isinstance(tokens, list):
        return ' '.join(tokens)
    elif isinstance(tokens, str):
        # Jika sudah string, coba evaluasi sebagai list
        try:
            tokens_list = eval(tokens)
            if isinstance(tokens_list, list):
                return ' '.join(tokens_list)
        except:
            return str(tokens)
    return str(tokens)

print("Mengkonversi lemmatized_ml tokens ke string...")
df['lemmatized_ml_text'] = df['lemmatized_ml'].apply(tokens_to_string)

# Cek hasil konversi
print("\nContoh data setelah konversi:")
print("Original lemmatized_ml:", df['lemmatized_ml'].iloc[0])
print("Converted text:", df['lemmatized_ml_text'].iloc[0][:300])
# Out:
# Mengkonversi lemmatized_ml tokens ke string...
#
# Contoh data setelah konversi:
# Original lemmatized_ml: ['grow', 'upon', 'seafood', 'corn', 'meal', 'bread', 'seafood', 'deep', 'fry', 'restaurant', 'exactly', 'advertise', 'excellent', 'cooked', 'one', 'superb', 'menu', 'deep', 'fry', 'seafood', 'experience', 'go', 'know', 'get', 'long', 'line', 'touristy', 'extremely', 'popular']
# Converted text: grow upon seafood corn meal bread seafood deep fry restaurant exactly advertise excellent cooked one superb menu deep fry seafood experience go know get long line touristy extremely popular

# %% [markdown]
# # Split

# %%
train_df, temp_df = train_test_split(
    df,
    test_size=0.3,
    stratify=df['sentiment_label'],
    random_state=42
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    stratify=temp_df['sentiment_label'],
    random_state=42
)

print(f"Training set: {len(train_df)} samples ({len(train_df)/len(df)*100:.1f}%)")
print(f"Validation set: {len(val_df)} samples ({len(val_df)/len(df)*100:.1f}%)")
print(f"Test set: {len(test_df)} samples ({len(test_df)/len(df)*100:.1f}%)")

print(f"\nTraining set class distribution:")
print(train_df['sentiment_label'].value_counts())
print(f"\nValidation set class distribution:")
print(val_df['sentiment_label'].value_counts())
print(f"\nTest set class distribution:")
print(test_df['sentiment_label'].value_counts())
# Out:
# Training set: 5369 samples (70.0%)
# Validation set: 1150 samples (15.0%)
# Test set: 1151 samples (15.0%)
#
# Training set class distribution:
# sentiment_label
# positive    4384
# negative     748
# neutral      237
# Name: count, dtype: int64
#
# Validation set class distribution:
# sentiment_label
# positive    939
# negative    160
# neutral      51
# Name: count, dtype: int64
#
# Test set class distribution:
# sentiment_label
# positive    940
# negative    161
# neutral      50
# Name: count, dtype: int64

# %% [markdown]
# # PREPARE FEATURES

# %%
# Prepare text data dari lemmatized_ml
X_train_text = train_df['lemmatized_ml_text'].fillna('').astype(str)
X_val_text = val_df['lemmatized_ml_text'].fillna('').astype(str)
X_test_text = test_df['lemmatized_ml_text'].fillna('').astype(str)

# Prepare numerical features
numerical_features = ['stars_review']
print(f"Numerical features: {numerical_features}")

X_train_numerical = train_df[numerical_features].fillna(0)
X_val_numerical = val_df[numerical_features].fillna(0)
X_test_numerical = test_df[numerical_features].fillna(0)

print(f"\nNumerical features shape:")
print(f"Training: {X_train_numerical.shape}")
print(f"Validation: {X_val_numerical.shape}")
print(f"Test: {X_test_numerical.shape}")

# Scale numerical features
scaler = StandardScaler()
X_train_numerical_scaled = scaler.fit_transform(X_train_numerical)
X_val_numerical_scaled = scaler.transform(X_val_numerical)
X_test_numerical_scaled = scaler.transform(X_test_numerical)

# Encode target variable
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_df['sentiment_label'])
y_val = label_encoder.transform(val_df['sentiment_label'])
y_test = label_encoder.transform(test_df['sentiment_label'])

print("Label encoding:")
for i, label in enumerate(label_encoder.classes_):
    print(f"  {i}: {label}")
# Out:
# Numerical features: ['stars_review']
#
# Numerical features shape:
# Training: (5369, 1)
# Validation: (1150, 1)
# Test: (1151, 1)
# Label encoding:
#   0: negative
#   1: neutral
#   2: positive

# %% [markdown]
# # TF-IDF Feature Extraction

# %%
print("Contoh teks training dari lemmatized_ml:")
print(X_train_text.iloc[0][:200] + "...")
# Out:
# Contoh teks training dari lemmatized_ml:
# stop drink hear live rhythm blue catch end set drink good reasonably price...

# %%
# TF-IDF dengan SublinearTF dan N-gram PADA LEMMATIZED TEXT
print("\nMembuat TF-IDF Vectorizer dengan SublinearTF dan N-gram pada lemmatized text...")
tfidf_vectorizer = TfidfVectorizer(
    sublinear_tf=True,
    ngram_range=(1, 3),
    max_features=8000,
    min_df=2,
    max_df=0.95,
    stop_words='english'
)

# Fit dan transform pada training data
print("Fitting TF-IDF pada lemmatized training data...")
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train_text)
X_val_tfidf = tfidf_vectorizer.transform(X_val_text)
X_test_tfidf = tfidf_vectorizer.transform(X_test_text)
print(f"TF-IDF dimensions - Training: {X_train_tfidf.shape}")
# Out:
# Membuat TF-IDF Vectorizer dengan SublinearTF dan N-gram pada lemmatized text...
# Fitting TF-IDF pada lemmatized training data...
# TF-IDF dimensions - Training: (5369, 8000)

# %% [markdown]
# # COMBINE TEXT AND NUMERICAL FEATURES

# %%
# Combine TF-IDF dengan numerical features
X_train_combined = hstack([X_train_tfidf, X_train_numerical_scaled])
X_val_combined = hstack([X_val_tfidf, X_val_numerical_scaled])
X_test_combined = hstack([X_test_tfidf, X_test_numerical_scaled])

# Konversi ke CSR format untuk mendukung indexing
X_train_combined = csr_matrix(X_train_combined)
X_val_combined = csr_matrix(X_val_combined)
X_test_combined = csr_matrix(X_test_combined)
print(f"Combined features dimensions - Training: {X_train_combined.shape}")
# Out:
# Combined features dimensions - Training: (5369, 8001)

# %% [markdown]
# # SMOTE

# %%
print("Before SMOTE:")
print(f"Class distribution: {Counter(y_train)}")

# Apply SMOTE pada combined features
smote = SMOTE(random_state=42)
X_train_combined_resampled, y_train_resampled = smote.fit_resample(X_train_combined, y_train)

print("After SMOTE:")
print(f"Class distribution: {Counter(y_train_resampled)}")
# Out:
# Before SMOTE:
# Class distribution: Counter({np.int64(2): 4384, np.int64(0): 748, np.int64(1): 237})
# After SMOTE:
# Class distribution: Counter({np.int64(2): 4384, np.int64(0): 4384, np.int64(1): 4384})

# %% [markdown]
# # Train CatBoost Model

# %%
param_grid = {
    'depth': [4, 6],
    'learning_rate': [0.1, 0.5],
    'l2_leaf_reg': [3]
}

# %%
# Use stratified k-fold for cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Grid search untuk multi-class
grid_search = GridSearchCV(
    CatBoostClassifier(random_state=42, verbose=False, loss_function='MultiClass'),
    param_grid,
    cv=cv,
    scoring='f1_macro',  # Gunakan f1_macro untuk multi-class
    verbose=2
)

grid_search.fit(X_train_combined_resampled, y_train_resampled)

print(f"Best parameters: {grid_search.best_params_}")
print(f"Best cross-validation score: {grid_search.best_score_:.4f}")

# Get best model
best_catboost_model = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END ..........depth=4, l2_leaf_reg=3, learning_rate=0.1; total time=  40.2s
# [CV] END ..........depth=4, l2_leaf_reg=3, learning_rate=0.1; total time=  37.5s
# [CV] END ..........depth=4, l2_leaf_reg=3, learning_rate=0.1; total time=  38.9s
# [CV] END ..........depth=4, l2_leaf_reg=3, learning_rate=0.1; total time=  38.8s
# [CV] END ..........depth=4, l2_leaf_reg=3, learning_rate=0.1; total time=  39.0s
# [CV] END ..........depth=4, l2_leaf_reg=3, learning_rate=0.5; total time=  38.7s
# [CV] END ..........depth=4, l2_leaf_reg=3, learning_rate=0.5; total time=  38.6s
# [CV] END ..........depth=4, l2_leaf_reg=3, learning_rate=0.5; total time=  38.7s
# [CV] END ..........depth=4, l2_leaf_reg=3, learning_rate=0.5; total time=  38.6s
# [CV] END ..........depth=4, l2_leaf_reg=3, learning_rate=0.5; total time=  51.6s
# [CV] END ..........depth=6, l2_leaf_reg=3, learning_rate=0.1; total time= 2.8min
# [CV] END ..........depth=6, l2_leaf_reg=3, learning_rate=0.1; total time= 2.9min
# [CV] END ..........depth=6, l2_leaf_reg=3, learning_rate=0.1; total time= 2.9min
# [CV] END ..........depth=6, l2_leaf_reg=3, learning_rate=0.1; total time= 2.9min
# [CV] END ..........depth=6, l2_leaf_reg=3, learning_rate=0.1; total time= 2.8min
# [CV] END ..........depth=6, l2_leaf_reg=3, learning_rate=0.5; total time= 2.8min
# [CV] END ..........depth=6, l2_leaf_reg=3, learning_rate=0.5; total time= 2.8min
# [CV] END ..........depth=6, l2_leaf_reg=3, learning_rate=0.5; total time= 2.6min
# [CV] END ..........depth=6, l2_leaf_reg=3, learning_rate=0.5; total time= 2.3min
# [CV] END ..........depth=6, l2_leaf_reg=3, learning_rate=0.5; total time= 2.3min
# Best parameters: {'depth': 6, 'l2_leaf_reg': 3, 'learning_rate': 0.5}
# Best cross-validation score: 0.9757

# %% [markdown]
# # Evaluation

# %%
# Convert test data to dense for prediction
X_test_combined_dense = X_test_combined.toarray()
y_test_pred = best_catboost_model.predict(X_test_combined_dense)

print("\nTEST SET PERFORMANCE Sentiment Analysis CatBoost:")
print(f"Accuracy: {accuracy_score(y_test, y_test_pred):.4f}")
print(f"F1-Score (Macro): {f1_score(y_test, y_test_pred, average='macro'):.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred, target_names=label_encoder.classes_))
# Out:
# TEST SET PERFORMANCE Sentiment Analysis CatBoost:
# Accuracy: 0.9036
# F1-Score (Macro): 0.7192
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.70      0.76       161
#      neutral       0.30      0.72      0.42        50
#     positive       0.99      0.95      0.97       940
#
#     accuracy                           0.90      1151
#    macro avg       0.71      0.79      0.72      1151
# weighted avg       0.94      0.90      0.92      1151

# %%
cm = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix Sentiment Analysis CatBoost')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # SHAP

# %%
sample_size = min(100, X_test_combined.shape[0])
X_test_sample = X_test_combined[:sample_size]

# Buat feature names untuk combined features
feature_names = list(tfidf_vectorizer.get_feature_names_out()) + numerical_features

print(f"Menggunakan {sample_size} samples untuk SHAP analysis...")

# Convert sparse matrix to dense untuk SHAP
X_test_sample_dense = X_test_sample.toarray()

# Create SHAP explainer untuk multi-class
explainer = shap.KernelExplainer(
    model=best_catboost_model.predict_proba,
    data=X_test_sample_dense,
    link="logit"
)

# Calculate SHAP values untuk semua kelas
print("Menghitung SHAP values...")
shap_values = explainer.shap_values(X_test_sample_dense, nsamples=100)

# Plot SHAP summary untuk setiap kelas
for i, class_name in enumerate(label_encoder.classes_):
    plt.figure(figsize=(12, 8))
    shap.summary_plot(shap_values[:,:,i], X_test_sample_dense,
                      feature_names=feature_names,
                      show=False, max_display=20)
    plt.title(f"SHAP Summary Plot - {class_name} Sentiment\nSentiment Analysis Catboost")
    plt.tight_layout()
    plt.show()
# Out:
# Menggunakan 100 samples untuk SHAP analysis...
# Menghitung SHAP values...
#   0%|          | 0/100 [00:00<?, ?it/s]
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=5.338e-01, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\explainers\_kernel.py:708: UserWarning: Linear regression equation is singular, a least squares solutions is used instead.
# To avoid this situation and get a regular matrix do one of the following:
# 1) turn up the number of samples,
# 2) turn up the L1 regularization with num_features(N) where N is less than the number of samples,
# 3) group features together to reduce the number of inputs that need to be explained.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=8.285e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.022e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=4.783e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=4.831e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.287e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.234e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=3.776e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=4.261e-01, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.155e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.734e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=3.079e-01, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.023e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=2.017e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.398e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=4.863e-01, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.432e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=1.568e-01, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=3.346e+00, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.265e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.632e+00, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.189e+00, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=4.208e+00, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=2.309e+00, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.735e+00, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.633e+00, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=8.896e-01, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.164e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=1.979e+00, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=3.051e+00, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=1.525e+00, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=5.754e-01, with an active set of 3 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=3.843e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=4.063e-01, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=3.478e-01, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=8.031e-01, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=3.680e-01, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=4.821e-01, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=3.138e-01, with an active set of 7 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(
# c:\Users\Kelvin Jonathan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_least_angle.py:723: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.646e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn(

# %%
# SHAP summary untuk numerical features saja
numerical_indices = [len(feature_names) - len(numerical_features) + i for i in range(len(numerical_features))]
shap_values_numerical = shap_values[:, numerical_indices, 1]

plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values_numerical, X_test_sample_dense[:, numerical_indices], 
                  feature_names=numerical_features,
                  show=False)
plt.title("SHAP Summary Plot - Numerical Features Only\nSublinear TF Sentiment Catboost")
plt.tight_layout()
plt.show()

# %%
shap_df = pd.DataFrame({
    'feature': feature_names,
    'importance': np.abs(shap_values[:,:,1]).mean(0)
})
shap_df = shap_df.sort_values('importance', ascending=False)

print("\nTop 20 Features by SHAP Importance:")
print(shap_df.head(20))

print("\nTop Numerical Features by SHAP Importance:")
numerical_shap = shap_df[shap_df['feature'].isin(numerical_features)]
print(numerical_shap)
# Out:
# Top 20 Features by SHAP Importance:
#                  feature  importance
# 8000        stars_review    3.859039
# 106             actually    0.075880
# 3220    half dozen fresh    0.050638
# 827          bread sauce    0.041053
# 29                  acme    0.036099
# 3211           guy shuck    0.035874
# 4680               onion    0.033266
# 1826          dish order    0.031907
# 7596            wait bad    0.031832
# 6732             special    0.030039
# 1068             checker    0.025594
# 606             best way    0.023724
# 1932        drink pretty    0.023569
# 7408           try dozen    0.023249
# 2873  good seafood gumbo    0.022926
# 5279                play    0.022554
# 2654      fun experience    0.022300
# 3403         house order    0.021512
# 6386        service okay    0.020097
# 3934          line worth    0.019865
#
# Top Numerical Features by SHAP Importance:
#            feature  importance
# 8000  stars_review    3.859039

# %% [markdown]
# # LIME

# %%
# Convert training sample to dense for LIME
training_sample = X_train_combined_resampled[:]

explainer_lime = lime.lime_tabular.LimeTabularExplainer(
    training_data=training_sample,
    feature_names=feature_names,
    class_names=label_encoder.classes_,
    mode='classification',
    random_state=42
)

# Pilih beberapa contoh untuk dijelaskan
print("Memilih contoh untuk interpretasi LIME...")

# Cari contoh untuk setiap kelas yang diprediksi dengan confidence tinggi
y_test_proba = best_catboost_model.predict_proba(X_test_combined_dense)
y_test_pred = best_catboost_model.predict(X_test_combined_dense)

examples_to_explain = []
for class_idx, class_name in enumerate(label_encoder.classes_):
    # Cari contoh dengan prediksi kelas tertentu dan confidence tinggi
    class_indices = np.where((y_test == class_idx) & (y_test_proba[:, class_idx] > 0.7))[0]
    if len(class_indices) > 0:
        examples_to_explain.append(class_indices[0])

# Jika tidak cukup contoh, tambahkan contoh pertama dari setiap kelas
if len(examples_to_explain) < len(label_encoder.classes_):
    for class_idx in range(len(label_encoder.classes_)):
        if class_idx not in [y_test[i] for i in examples_to_explain]:
            class_indices = np.where(y_test == class_idx)[0]
            if len(class_indices) > 0:
                examples_to_explain.append(class_indices[0])

# Batasi maksimal 3 contoh (satu per kelas)
examples_to_explain = examples_to_explain[:3]

for i, example_idx in enumerate(examples_to_explain):
    print(f"\n--- Contoh {i+1} ---")

    # Get instance untuk dijelaskan
    instance = X_test_combined_dense[example_idx]
    true_label = y_test[example_idx]
    predicted_label = y_test_pred[example_idx]
    predicted_proba = y_test_proba[example_idx]

    # Pastikan predicted_label adalah integer, bukan numpy array
    predicted_label_int = int(predicted_label)
    
    # Dapatkan teks asli
    original_text = test_df.iloc[example_idx]['normalized_text']
    lemmatized_text = test_df.iloc[example_idx]['lemmatized_ml_text']

    print(f"Original Text: {original_text[:200]}...")
    print(f"Lemmatized Text: {lemmatized_text[:200]}...")
    print(f"Actual: {label_encoder.classes_[true_label]}")
    print(f"Predicted: {label_encoder.classes_[predicted_label_int]}")
    print("Prediction Probabilities:")
    for j, class_name in enumerate(label_encoder.classes_):
        print(f"  {class_name}: {predicted_proba[j]:.4f}")

    # LIME explanation
    print("\nLIME Explanation:")

    exp = explainer_lime.explain_instance(
        instance,
        best_catboost_model.predict_proba,
        num_features=30,
        top_labels=3
    )

    # Tampilkan explanation untuk prediksi yang dipilih
    label_to_explain = predicted_label_int

    try:
        # Tampilkan explanation sebagai list
        explanation_list = exp.as_list(label=label_to_explain)

        # Buat plot manual
        plt.figure(figsize=(10, 6))

        # Ambil features dan weights
        features = [x[0] for x in explanation_list[:30]]
        weights = [x[1] for x in explanation_list[:30]]

        # Warna berdasarkan interpretasi
        colors = ['green' if x > 0 else 'red' for x in weights]

        # Buat horizontal bar plot
        y_pos = np.arange(len(features))
        plt.barh(y_pos, weights, color=colors)
        plt.yticks(y_pos, features)
        plt.xlabel('Weight')
        plt.title(f"LIME Explanation - Contoh {i+1}\n(Actual: {label_encoder.classes_[true_label]}, Predicted: {label_encoder.classes_[predicted_label_int]})")

        # Tambah garis vertikal di 0
        plt.axvline(x=0, color='black', linestyle='-', alpha=0.5)

        plt.tight_layout()
        plt.show()

        # Tampilkan fitur yang paling berpengaruh
        print("\nTop Features yang Mempengaruhi Prediksi:")
        for feature, weight in explanation_list[:30]:
            if weight > 0:
                influence = f"MENDORONG {label_encoder.classes_[label_to_explain]}"
            else:
                # Cari kelas dengan probabilitas tertinggi selain yang diprediksi
                other_probs = [(j, prob) for j, prob in enumerate(predicted_proba) if j != label_to_explain]
                if other_probs:
                    other_class_idx = max(other_probs, key=lambda x: x[1])[0]
                    influence = f"MENDORONG {label_encoder.classes_[other_class_idx]}"
                else:
                    influence = "MENDORONG kelas lain"
            print(f"  {feature}: {weight:.4f} ({influence})")

    except Exception as e:
        print(f"Error dalam menampilkan plot LIME: {e}")
        # Fallback: coba tampilkan explanation tanpa spesifik label
        try:
            explanation_list = exp.as_list()
            print("\nTop Features yang Mempengaruhi Prediksi (Text Only - All Labels):")
            for feature, weight in explanation_list[:30]:
                print(f"  {feature}: {weight:.4f}")
        except Exception as e2:
            print(f"Juga gagal menampilkan explanation tanpa label: {e2}")
        continue
# Out:
# Memilih contoh untuk interpretasi LIME...
#
# --- Contoh 1 ---
# Original Text: Ehhhhh I do not know what the big deal about this places it is just so so We waited in line for an hour and minutes to eat here and it really was not that great and way overpriced I would not go back ...
# Lemmatized Text: ehhhhh know big deal place wait line hour minute eat really great way overprice would go back would recommend good place eat new orleans...
# Actual: negative
# Predicted: negative
# Prediction Probabilities:
#   negative: 0.9978
#   neutral: 0.0021
#   positive: 0.0001
#
# LIME Explanation:
# Top Features yang Mempengaruhi Prediksi:
#   stars_review: -0.0066 (MENDORONG neutral)
#   eat: 0.0014 (MENDORONG negative)
#   fresh: -0.0010 (MENDORONG neutral)
#   big deal: 0.0008 (MENDORONG negative)
#   place: 0.0008 (MENDORONG negative)
#   really great: -0.0007 (MENDORONG neutral)
#   good place eat: 0.0007 (MENDORONG negative)
#   great way: -0.0006 (MENDORONG neutral)
#   new: -0.0006 (MENDORONG neutral)
#   place wait: 0.0005 (MENDORONG negative)
#   wait line hour: 0.0005 (MENDORONG negative)
#   minute: 0.0005 (MENDORONG negative)
#   overprice: 0.0005 (MENDORONG negative)
#   place eat new: -0.0004 (MENDORONG neutral)
#   wait line: -0.0004 (MENDORONG neutral)
#   deal: -0.0004 (MENDORONG neutral)
#   minute eat: -0.0003 (MENDORONG neutral)
#   way: -0.0003 (MENDORONG neutral)
#   eat new orleans: 0.0003 (MENDORONG negative)
#   eat new: 0.0003 (MENDORONG negative)
#   good place: -0.0002 (MENDORONG neutral)
#   place wait line: -0.0002 (MENDORONG neutral)
#   big: -0.0001 (MENDORONG neutral)
#   eat really: 0.0001 (MENDORONG negative)
#   line hour: -0.0001 (MENDORONG neutral)
#   know: 0.0001 (MENDORONG negative)
#   hour minute: -0.0001 (MENDORONG neutral)
#   recommend: 0.0000 (MENDORONG negative)
#   orleans: -0.0000 (MENDORONG neutral)
#   place eat: 0.0000 (MENDORONG negative)
#
# --- Contoh 2 ---
# Original Text: We were lucky we got to this place when there was no line outside We ordered oysters raw chargrilled oysters and gumbo Everything was just OK The chargrilled oysters were great first bite but then bec...
# Lemmatized Text: lucky get place line outside ordered raw gumbo everything ok great first bite become way salty go across street cheaper well...
# Actual: neutral
# Predicted: neutral
# Prediction Probabilities:
#   negative: 0.0763
#   neutral: 0.9106
#   positive: 0.0131
#
# LIME Explanation:
# Top Features yang Mempengaruhi Prediksi:
#   place line outside: 0.0050 (MENDORONG neutral)
#   raw gumbo: 0.0021 (MENDORONG neutral)
#   ordered raw: 0.0019 (MENDORONG neutral)
#   ok great: 0.0012 (MENDORONG neutral)
#   gumbo ok: 0.0012 (MENDORONG neutral)
#   way salty: 0.0011 (MENDORONG neutral)
#   place line: 0.0010 (MENDORONG neutral)
#   lucky: 0.0009 (MENDORONG neutral)
#   bite: 0.0005 (MENDORONG neutral)
#   ordered: 0.0005 (MENDORONG neutral)
#   bread: 0.0004 (MENDORONG neutral)
#   line: 0.0003 (MENDORONG neutral)
#   know: 0.0003 (MENDORONG neutral)
#   raw: 0.0003 (MENDORONG neutral)
#   line outside: 0.0003 (MENDORONG neutral)
#   street: 0.0003 (MENDORONG neutral)
#   try: -0.0002 (MENDORONG negative)
#   gumbo: -0.0002 (MENDORONG negative)
#   think: -0.0002 (MENDORONG negative)
#   way: 0.0002 (MENDORONG neutral)
#   outside: 0.0002 (MENDORONG neutral)
#   po boy: -0.0002 (MENDORONG negative)
#   right: 0.0002 (MENDORONG neutral)
#   fried: 0.0001 (MENDORONG neutral)
#   nola: -0.0001 (MENDORONG negative)
#   salty: 0.0001 (MENDORONG neutral)
#   great: 0.0001 (MENDORONG neutral)
#   boy: -0.0001 (MENDORONG negative)
#   ok: 0.0001 (MENDORONG neutral)
#   wait: -0.0000 (MENDORONG negative)
#
# --- Contoh 3 ---
# Original Text: Everytime I visit New Orleans Acme is among my first three stops Excellent...
# Lemmatized Text: everytime visit new orleans acme among first three stop excellent...
# Actual: positive
# Predicted: positive
# Prediction Probabilities:
#   negative: 0.0000
#   neutral: 0.0007
#   positive: 0.9993
#
# LIME Explanation:
# Top Features yang Mempengaruhi Prediksi:
#   acme stop: 0.0056 (MENDORONG positive)
#   stars_review: 0.0047 (MENDORONG positive)
#   new orleans acme: 0.0025 (MENDORONG positive)
#   want: -0.0016 (MENDORONG neutral)
#   everytime: 0.0016 (MENDORONG positive)
#   orleans acme: 0.0016 (MENDORONG positive)
#   visit new: 0.0016 (MENDORONG positive)
#   visit new orleans: 0.0010 (MENDORONG positive)
#   good: 0.0010 (MENDORONG positive)
#   eat: -0.0010 (MENDORONG neutral)
#   fry: 0.0010 (MENDORONG positive)
#   acme: 0.0009 (MENDORONG positive)
#   excellent: 0.0007 (MENDORONG positive)
#   place: -0.0007 (MENDORONG neutral)
#   tourist: -0.0007 (MENDORONG neutral)
#   new: 0.0007 (MENDORONG positive)
#   time: -0.0006 (MENDORONG neutral)
#   orleans: 0.0005 (MENDORONG positive)
#   best: -0.0005 (MENDORONG neutral)
#   sauce: 0.0004 (MENDORONG positive)
#   po: 0.0004 (MENDORONG positive)
#   small: 0.0004 (MENDORONG positive)
#   stop: 0.0004 (MENDORONG positive)
#   wait: -0.0002 (MENDORONG neutral)
#   little: -0.0002 (MENDORONG neutral)
#   boy: 0.0002 (MENDORONG positive)
#   new orleans: -0.0001 (MENDORONG neutral)
#   minute: 0.0000 (MENDORONG positive)
#   visit: 0.0000 (MENDORONG positive)
#   seafood: -0.0000 (MENDORONG neutral)

# %% [markdown]
# # Save Model

# %%
model_artifacts = {
    'model': best_catboost_model,
    'tfidf_vectorizer': tfidf_vectorizer,
    'scaler': scaler,
    'label_encoder': label_encoder,
    'feature_names': feature_names,
    'numerical_features': numerical_features
}

joblib.dump(model_artifacts, 'Sentiment_Analysis_CatBoost.pkl')
# Out:
# ['Sentiment_Analysis_CatBoost.pkl']
